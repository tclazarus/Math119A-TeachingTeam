# %% [markdown]
# ## <span style='color:#e91e63'> Intro to Lab Homework \(Fri, Aug 28\) </span>
#
# <span style='color:#e91e63'>We will use Sagemath \(mathematical computational tool\) in Binder.  Coding cells can be used to "tell" Sage what information to remember and use\-\-this allows us greater computational power! </span>
#
# <span style='color:#e91e63'> Since we have more flexibility in computation, there are some new things to be careful about in defining values and functions.  </span>
#
# <span style='color:#e91e63'> **WARNING!!**  Binder does not save your work as you go.  If you close this window or leave it inactive for too long, Binder will cut access to the server used for the computations.  In order to continue working on a lab after class, make sure to download (File -> Download) this notebook.  To open it again, just follow the link to Binder and then upload your saved document.  </span>

# %% [markdown]
# #### <span style='color:#3f51b5'>**Question 0: General Information**</span>
#
# This file you just opened is called a Jupyter Notebook and it is the main way we will interface with the computational tools provided by the computer, specifically through the coding language called Sagemath.  Think of these notebooks as an instruction manual for how to tell the computer what calculations you would like it to do for you.  We speak to the computer in the language of Sagemath and it will speak the same language back, so our first job is to start to learn how to communicate properly.
#
# Computers are extremely literal, so they will not try to infer what you meant to say, they will just do exactly as you said.  Therefore we need to be extra precise and explicit when we are giving commands to the computer.  We will make these commands in coding cells below.  You can see when you are working in a coding cell because the background color will be slightly darker and there will be a small bracket, $[ \hspace{.2cm} ]$, to the left side.  We will start this class by asking the computer to evaluate some simple mathematical expressions before we transition to more interesting and involved tasks.

# %% [markdown]
# #### <span style='color:#3f51b5'>**Question 1: Some basic commands to practice executing code**</span>
#
# This first question will illustrate the order in which the computer will read and how it will answer the commands you give it.  Anything typed into a coding cell will be interpreted as code to be run.  Often times, we may want to annotate code with comments to say what the code is doing or what the terms in the code mean.  These comments will begin with a pound sign \(AKA hash tag, \#\). Comments will be ignored for the computation, but they may be helpful to give context or the reason for why we are choosing to run a particualr computation.
#
# Note: To execute the code in the cells below, press "shift" \+ "enter".

# %% [markdown]
# <u>**Question 1.1:**</u><u> </u>You will execute the code in a cell below by pressing "shift" \+ "enter". Try with one line of code first. Try below.
#
# Compute the square root of 625 by pressing 'shift \+ enter' to compute \(for Mac users, try 'command \+ enter'\).  Since we are only asking the computer to compute a value, it should return to us the final answer.

# %%
# Code for Question 1.1: 
sqrt(625)
# Out:
# 25

# %% [markdown]
# <u>**Question 1.2:**</u><u> </u> Comments in a code are ignored.  Run the cell below and compare this result with your previous result from Question 1.1.

# %%
# Code for Question 1.2: Compute the square root of 625 by pressing 'shift + enter' to compute (for Mac users, try 'command + enter')
sqrt(625) # blah blah blah this is a comment
# so is this
# Out:
# 25

# %% [markdown]
# <u>**Question 1.3:**</u><u> </u> If there are multiple lines of code in a cell, the computation will be completed in order from top to bottom, with only the final result displayed.  Run the cell below and notice the output that Sage displays.

# %%
# Code for Question 1.3: 
sqrt(625)
84 + 3
# Out:
# 87

# %% [markdown]
# <u>**Question 1.4:**</u> Run the cell below and compare this result with Question 1.3.

# %%
# Code for Question 1.4: 
84 + 3
sqrt(625)
# Out:
# 25

# %% [markdown]
# <u>**Question 1.5:**</u> When multiplying numbers, we need to use an asterisk between anything that is multiplied together. Modify the code below using an asterisk so that the output cell gives you 100.  The first cell here is "locked" so that you can't accidentally delete the code you need for this question.  To be able to modify it, just highlight and copy the code, then paste it into the editable cell below and modify to create code that answers the given question.

# %%
# Code to modify for Question 1.5: 
4 25 # This is the line of "code" you should modify, according to instructions above.

# %%
# Copy and Paste, then modify here
4*25 # This is the line of "code" you should modify, according to instructions above.
# Out:
# 100

# %% [markdown]
# #### <span style='color:#3f51b5'>**Question 2: Some basic commands to practice defining parameters**</span>
#
# We can define functions and values in Sage manually.  We'll start with a basic example where we use parameter values.  Syntax matters\-\-spelling, capitalization, and spacing are all important.
#
# In our course, we'll refer to "parameters" as a fixed value that we refer back to by a particular name.  Unlike input and output variables, parameters will not change values, although we may reference a parameter in computations later on.
#
# Telling Sage to remember a particular parameter value or a function will make our future computations shorter because we won't have to write out all the individual steps each time; we can just ask Sage to bring back the values that we told it to remember for us.  The key difference between asking Sage to remember something and to return the value of something is the inclusion of an equals sign "=".  If we include an equals sign, we are telling Sage to remember something.  If we do not include an equals sign, then we are asking Sage to actually compute something.  In the parts below, pay attention to when we want to ask Sage to remember something for us versus when we want it to use the values it is remembering to actually compute something.

# %% [markdown]
# <u>**Question 2.1:**</u> **Defining a parameter**. When defining values or functions, we are only telling Sagemath to "remember" information.  No output cell is needed.  For example, ${\tt cat = 6}$ tells Sage to remember that the parameter named "cat" has the value of 6.  Read the comment in the first line of code and run the cell.

# %%
# Code for Question 2.1: Execute the code below so that you can reference these values in later cells.
parameter1 = 25
Parameter2 = sqrt(9)

# %% [markdown]
# <u>**Question 2.2:**</u> **Retrieving a parameter value.**  Now that you have defined values, you can retrieve those values in an output cell by "calling" that name.  To "call" a parameter, type the parameter name and run the cell. Follow instructions in the comment.

# %%
# Question 2.2: Determine which parameter to "call" from Question 2.1 so that you have an output cell that displays the number 3.
Parameter2
# Out:
# 3

# %% [markdown]
# <u>**Question 2.3:**</u><u> </u>**Using parameter values in computation.**  Based on the information from Questions 2.1 and 2.2, combine the two different parameters using addition, multiplication, subtraction, or division so that your output cell shows the number 75.  <i>Reminder</i>: syntax and spelling matter!

# %%
# Code for Question 2.3: 
parameter1 * Parameter2
# Out:
# 75

# %% [markdown]
# <u>**Question 2.4:**</u> **Correcting syntax.** The following code will result in an error because parameter name(s) are incorrect.  There is also a second error in the same line of code.  Fix the syntax so that you correctly combine parameter values with an output cell that displays the value 8.

# %%
# Code for Question 2.4:
sqrt(Parameter1 + parameter2

# %%
# Copy and Paste, then modify here
sqrt(parameter1) + Parameter2
# Out:
# 8

# %% [markdown]
# #### <span style='color:#3f51b5'>**Question 3: Running code in a single cell**</span>
#
# Practice writing some of your own code all in a <u>single</u> cell.  You can use "enter" to drop down to the next line, and "shift"+"enter" to run the full cell.
#
# 1. Define a parameter so that your first name is equal to the number of letters in your first name.
#
# 2. Define a parameter so that your last name is equal to the number of letters in your last name.
#
# 3. Define a function that computes the difference of these two parameters and adds the input value. Name this function your favorite animal.  <i>Note: The difference between a parameter and a function.  A function has to indicate the independent variable, but since a parameter is just a number, the parameter does not.  E.g. $cat$ is a parameter named cat, but $cat(x)$ is a function named cat that uses $x$ as the independent variable.</i>
#
# - Example: bunny(x) = Tynan - Lazarus + x
#
# 4. Test your function by evaluating x = 0. (Hint: use function notation from Step 3)
#
# 5. Update the parameter you defined in Step 1 to be 100.
#
# 6. Reevaluate the same function at x = 0 without defining anything else new.
#
# Note that you should have <u><b>four</b></u> lines of code when you finish making this cell.

# %%
# Code for Question 3:
Tynan = 5
Lazarus = 7
cat(x)=Tynan - Lazarus + x
cat(0)
# Out:
# -2

# %%
# Code for Question 3:
Tynan = 100
Lazarus = 7
cat(x)=Tynan - Lazarus + x
cat(0)
# Out:
# 93

# %% [markdown]
# #### <span style='color:#3f51b5'>**Question 4: Introducing functions**</span>
#
# <u>**Question 4.1:**</u> Copy the code below and choose values for the given parameters \(replace the asterisks \*\*\* with the values described in the comments).  Then run the cell and answer the comment shown in the final line.

# %%
# Code for Question 4.1
m = ***   #pick some decimal value
b = ***  #pick your favorite number here
y(x) = m*x +b
point(x) = [x, y(x)]
point(0)  # What is the mathematical significance of this point?

# %%
# Copy and Paste, then modify here
# Code for Question 4.1
m = 0.422   #pick some decimal value
b = 6  #pick your favorite number here
y(x) = m*x +b
point(x) = [x, y(x)]
point(0)  # What is the mathematical significance of this point?
# Out:
# (0, 6)

# %%
#This number is the vertical intercept, where the graph of the function named y will cross the vertical axis.

# %% [markdown]
# <u>**Question  4.2:**</u>  Run the code below.  Based on the ouptut cell, what do you think this command is telling Sage to do?

# %%
plot(y,x, (x, -100,100))
# Out:
# Graphics object consisting of 1 graphics primitive
