# %%
gpa=[(0,3.6), (1,3.3), (2,3), (3,3.6), (4,4)]
hours=[(0,70),(1,50), (2,20),(3,30),(4,80)]
scatter_plot(gpa, frame=True,markersize=100, facecolor='blue', axes_labels=["week","GPA"])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gpa=[(0,3.6), (1,3.3), (2,3), (3,3.6), (4,4)]
hours=[(0,70),(1,50), (2,20),(3,30),(4,80)]
scatter_plot(hours, frame=True,markersize=100, facecolor='blue', axes_labels=["week","hours"])
# Out:
# Graphics object consisting of 1 graphics primitive
